# %%
import pandas as pd

# %%
name_df   = pd.read_csv('baby_name_full_list.csv')
name_list = name_df['Name']

# %%
for i in range(len(name_list)):
    name_list[i] = name_list[i].lower()

# %%
len(name_list)
# Out:
# 1879

# %%
'","'.join(name_list)
# Out:
# 'aaden","aarav","aaron","aayan","abbie","abdul","abner","abram","adams","addie","adlai","adolf","adron","aedan","agnes","ahmad","ahmed","ahmir","aidan","aiden","aidyn","akeem","akira","albin","alcee","alden","aleck","alfie","alger","algie","algot","alice","allan","allen","allie","allyn","almer","almon","almus","alois","aloys","alpha","alton","alvah","alvan","alver","alvia","alvie","alvin","alvis","alwin","amado","amare","amari","amasa","ameer","amias","ammon","ancel","ancil","andon","andra","andre","angel","angus","annie","ansel","anson","anton","anwar","arbie","arden","arian","ariel","aries","arjun","arlan","arlen","arley","arlie","arlin","arlis","arlyn","arman","armin","arnav","arnie","arron","artie","artis","arvel","arvid","arvil","arvin","aryan","ashby","asher","atlas","aubra","audie","autry","avery","axton","ayaan","aydan","ayden","aydin","aziel","baker","banks","baron","barry","basil","benji","benny","berry","beryl","betty","bilal","billy","bjorn","blain","blair","blake","blane
# ...

# %%
correct_list = ['kylie']
correct_list = correct_list*3000
correct_list
'","'.join(correct_list)
# Out:
# 'kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie","kylie
# ...
